# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ercot_2019_wind = pd.read_csv('ERCOT_2019_Hourly_Wind_Output.csv', header=0, error_bad_lines=False)
ercot_2019_wind.head()
# Out:
# b'Skipping line 8766: expected 13 fields, saw 18\nSkipping line 8767: expected 13 fields, saw 18\nSkipping line 8768: expected 13 fields, saw 18\nSkipping line 8769: expected 13 fields, saw 18\nSkipping line 8770: expected 13 fields, saw 18\nSkipping line 8771: expected 13 fields, saw 18\nSkipping line 8772: expected 13 fields, saw 18\nSkipping line 8773: expected 13 fields, saw 18\nSkipping line 8774: expected 13 fields, saw 18\nSkipping line 8775: expected 13 fields, saw 18\nSkipping line 8776: expected 13 fields, saw 18\nSkipping line 8777: expected 13 fields, saw 18\nSkipping line 8778: expected 13 fields, saw 18\nSkipping line 8779: expected 13 fields, saw 18\nSkipping line 8780: expected 13 fields, saw 18\nSkipping line 8781: expected 13 fields, saw 18\nSkipping line 8782: expected 13 fields, saw 18\nSkipping line 8783: expected 13 fields, saw 18\nSkipping line 8784: expected 13 fields, saw 18\nSkipping line 8785: expected 13 fields, saw 18\nSkipping line 8786: expected 13 fiel
# ...

# %%
db = ercot_2019_wind.rename(columns={'ERCOT Load, MW': 'ercot_load_mw', 'Total Wind Output, MW': 'wind_total_output_mw', 'Total Wind Installed, MW': 'wind_installed_total', 'Wind Output, % of Load': 'wind_output_percent_of_load', 'Wind Output, % of Installed': 'wind_output_percent_installed'})

# %%
db.head()
# Out:
#                                                                                                                                                                                       numbers: Table 1
# time-date stamp     Date   ERCOT Load, MW Total Wind Output, MW Total Wind Installed, MW Wind Output, % of Load Wind Output, % of Installed 1-hr MW change 1-hr % change NaN NaN NaN               NaN
# 01/01/2019 00:00:00 Jan-01 36968          14128                 22607                    38.2                   62                          NaN            NaN           NaN NaN NaN               NaN
# 01/01/2019 01:00:00 Jan-01 37116          14237                 22607                    38.4                   63                          108.6          0.768         NaN NaN NaN               NaN
# ...

# %%
db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 8762 entries, ('time-date stamp', 'Date', 'ERCOT Load, MW', 'Total Wind Output, MW', 'Total Wind Installed, MW', 'Wind Output, % of Load', 'Wind Output, % of Installed', '1-hr MW change', '1-hr % change', nan, nan, nan) to ('comments: Table 1', nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan)
# Data columns (total 1 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   numbers: Table 1  0 non-null      float64
# dtypes: float64(1)
# memory usage: 2.1+ MB

# %%
db['Date'].groupby().sum('ERCOT Load, MW')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-a15a45cb8cc0> in <module>
# ...
